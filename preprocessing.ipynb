# %% [markdown]
# **<h1>Data Preprocessing</h1>**
# <h3> Take out only the necessary parts of the data given by the xlsx file and switch to a usable csv file </h3>

# %% [markdown]
# **<h2>1. making class.csv file</h2>**
# * Purpose: To create processed data that expresses each student's course in numbers
# * Input : Semester, Student, Class Information
# * output : the undergraduate number of each student's class per line

# %% [markdown]
# 1) A function that converts the subject code into an undergraduate code

# %%
def toCode(code) :
    if (('ISE' in code) or(code=='국제어문학부')):
        return 1
    elif (('LAW' in code) or('UIL' in code) or(code=='법학부')):
        return 2
    elif (('CSW' in code) or(code=='상담심리사회복지학부')):
        return 3
    elif (('CCC' in code) or(code=='커뮤니케이션학부')):
        return 4
    elif (('MEC' in code) or('GMP' in code) or(code=='경영경제학부')):
        return 5
    elif (('CUE' in code) or(code=='공간환경시스템공학부')):
        return 6
    elif (('BFT' in code) or(code=='생명과학부')):
        return 7
    elif (('IID' in code)  or(code=='콘텐츠융합디자인학부')):
        return 8
    elif (('ECE' in code) or('ITP' in code) or(code=='전산전자공학부')):
        return 9
    elif (('HMM' in code) or(code=='기계제어공학부')):
        return 10
    elif (('SIT' in code) or(code=='ICT창업학부')):
        return 11
    elif (('CCE' in code) or(code=='창의융합교육원(인문사회)')):
        return 12
    elif (('GEK' in code) or ('ISL' in code) or ('PCO' in code) or ('GCS' in code) or(code=='글로벌리더십학부')):
        return 13
    else:
        return 0 #none

# %% [markdown]
# 2) Draw only the columns you need to make them into a data frames

# %%
import pandas as pd
from pandas import DataFrame
import csv

# Change the df_test.xlsx file to the dataframe of the school year and subject code
df = pd.read_excel("rawdata.xlsx", engine = "openpyxl")
df_class = pd.DataFrame(df, columns=['학번', '과목코드'])

# %% [markdown]
# 3) write class.csv

# %%
# Class.csv, if you're a student, add it to the side or down
fc = open('class.csv', 'w', newline='')
wrc = csv.writer(fc)

codes = []
prestudent=15604

for i in range(0, len(df_class)):
    if(df_class.loc[i, '학번'] != prestudent):
        prestudent = df_class.loc[i, '학번']
        if(len(codes) < 22):
            for i in range (len(codes), 22):
                codes.append(0)
        wrc.writerow(codes)
        codes = []
    codes.append(toCode(df_class.loc[i, '과목코드']))

fc.close()
# Out:
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# ...

# %% [markdown]
# **<h2>2.Create major.csv file</h2>**
# * Purpose: To create processed data that expresses which department each student eventually chose
# * Input : Semester, Student, Class Information
# * output : Each student's department is represented by code in the same order as class.csv

# %% [markdown]
# 1) Draw only the columns you need to make them into a data frames

# %%
# Change df_test.xlsx file to dataframe for school year, department
df_major = pd.DataFrame(df, columns=['학번', '현학부'])

# %% [markdown]
# 2) Write each student's undergraduate code in major.csv

# %%
# 2) Write each student's undergraduate code in major.csv
fm = open('major.csv', 'w', newline='')
wrm = csv.writer(fm)

prestudent=15604

for i in range(0, len(df_class)):
    if(df_class.loc[i, '학번'] != prestudent):
        prestudent = df_major.loc[i, '학번']
        majorresult = []
        majorresult.append(toCode(df_major.loc[i, '현학부']))
        wrm.writerow(majorresult)

fm.close()
